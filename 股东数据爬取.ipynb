# %%
import logging
import re
from urllib.parse import urljoin,urlencode
import multiprocessing
import time
import json
from os import makedirs
from os.path import exists
import pandas as pd
from lxml import etree

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ChromeOptions

logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(levelname)s: %(message)s')

# 基础网址和爬取页码数量设定
BASE_URL='https://www.9fzt.com/marketCenter/aStockMarket.html?tab=0'
TOT_PAGEs=4

# %%
# %%
def get_browser():
    option=ChromeOptions()
    option.add_experimental_option('excludeSwitches',['enable-automation'])
    option.add_experimental_option('useAutomationExtension',False)
    # 设置不显式地显示浏览器
    option.add_argument('--headless')
    browser=webdriver.Chrome(options=option)
    browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument",
                            {'source': 'Object.defineProperty(navigator,"webdriver",{get:()=>undefind})'})
    browser.implicitly_wait(10)
    return browser

# %%
def parse_page(page_html,protol_type='https:'):
    pattern=re.compile('序号(.*)',re.S)
    stock_urls=re.findall(pattern,page_html)
    pattern=re.compile('<a href="(.*?)".*? class="bluelink ff_din-medium fw-500" target="_blank" rel="noopener">',re.S)
    stock_urls=re.findall(pattern,str(stock_urls))
    stock_urls=[urljoin(protol_type,url) for url in stock_urls]
    return stock_urls

# %%
def scrape_stock_list(browser,page_num):
    browser.get(BASE_URL)
    urls=[]
    WebDriverWait(browser,20,0.5).until(lambda browser:len(
        browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    for page in range(page_num):
        urls+=(parse_page(browser.page_source))
        time.sleep(0.1)
        ac=ActionChains(browser)
        # 鼠标移动到下一页按钮上
        ac.move_to_element(browser.find_element_by_name('whj_nextPage')).perform()
        # 点击确定跳转至下一页
        ac.click(browser.find_element_by_name('whj_nextPage')).perform()
        time.sleep(0.1)
        WebDriverWait(browser,10,0.5).until(lambda browser: len(
            browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    print(urls)
    return urls

# %%
def scrape_stockprice_page(browser,url):
    logging.info('scraping %s...',url)
    browser.get(url)
    WebDriverWait(browser,60,2).until(lambda browser: browser.find_element_by_id('stockprice').text != '--')
    return browser.page_source

# %%
def scrape_company_list(browser,urls):
    companys=[]
    for url in urls:
        logging.info('scraping %s...',url)
        browser.get(url)
        logging.info('scraping 股东研究...')
        browser.find_element_by_link_text('股东研究').click()
        browser.switch_to.window(browser.window_handles[1])
        WebDriverWait(browser,10,2).until(lambda browser: len(
           browser.find_element(By.XPATH,'//*[@id="sdgd"]/div[2]/div/div/section/div[2]/div/div/div/div/div/table/tbody/tr[1]/td[6]/span').text)>0)
        shareholder=browser.page_source
        browser.close()
        browser.switch_to.window(browser.window_handles[0])
        #shareholder = None

        companys.append([shareholder])
    return companys

# %%
# 使用xpath匹配
shareholer_name_xpath='//*[@id="SHNameTopTenSH0"]/text()'
shareholer_nature_xpath='//*[@id="SHNatureTopTenSH0"]/text()'
share_type_xpath='//*[@id="ShareTypeTopTenSH0"]/text()'
share_amount_xpath='//*[@id="sdgd"]/div[2]/div/div/section/div[2]/div/div/div/div/div/table/tbody/tr[1]/td[5]/span/text()'
share_ratio_xpath='//*[@id="sdgd"]/div[2]/div/div/section/div[2]/div/div/div/div/div/table/tbody/tr[1]/td[6]/span/text()'

def parse_company_data(html):
    html=etree.HTML(html)
    shareholer_name=html.xpath(shareholer_name_xpath)[0]
    shareholer_nature=html.xpath(shareholer_nature_xpath)[0]
    share_type=html.xpath(share_type_xpath)[0]
    share_amount=html.xpath(share_amount_xpath)[0]
    share_ratio=html.xpath(share_ratio_xpath)[0]

    return [shareholer_name,shareholer_nature,share_type,share_amount,share_ratio]

# %%
def get_table_company_data(data):
    table=pd.DataFrame(columns=['shareholer_name','shareholer_nature','share_type','share_amount','share_ratio'])
    for item in data:
        table.loc[len(table)]=parse_company_data(item)
    return table

# %%
browser=get_browser()
urls=scrape_stock_list(browser,TOT_PAGEs)
#urls=['https://stock.9fzt.com/index/bj_870204.html']

companys=scrape_company_list(browser,urls)
data=[company[0] for company in companys]

company_data_table=get_table_company_data(data)
#print(company_data_table)

company_data_table.to_csv('share_data_table.csv',index=False,encoding='gbk')
# Out:
# 2023-07-04 19:20:04,097 - INFO: scraping https://stock.9fzt.com/index/sz_301488.html...
# ['https://stock.9fzt.com/index/sz_301488.html', 'https://stock.9fzt.com/index/bj_833533.html', 'https://stock.9fzt.com/index/sz_301007.html', 'https://stock.9fzt.com/index/sz_301255.html', 'https://stock.9fzt.com/index/sz_300489.html', 'https://stock.9fzt.com/index/sz_301221.html', 'https://stock.9fzt.com/index/sz_300552.html', 'https://stock.9fzt.com/index/sh_688280.html', 'https://stock.9fzt.com/index/sz_300503.html', 'https://stock.9fzt.com/index/sz_300549.html', 'https://stock.9fzt.com/index/sh_688331.html', 'https://stock.9fzt.com/index/bj_831278.html', 'https://stock.9fzt.com/index/sh_688147.html', 'https://stock.9fzt.com/index/sh_688123.html', 'https://stock.9fzt.com/index/bj_836221.html', 'https://stock.9fzt.com/index/sh_688326.html', 'https://stock.9fzt.com/index/sz_301099.html', 'https://stock.9fzt.com/index/sh_688071.html', 'https://stock.9fzt.com/index/sz_300496.html', 'https://stock.9fzt.com/index/sz_301183.html', 'https://stock.9fzt.com/index/sz_301488.html', 'https://stock.9fzt.com/index/bj_833533.html', 'https://stock.9fzt.com/index/sz_301007.html', 'https://stock.9fzt.com/index/sz_301255.html', 'https://stock.9fzt.com/index/sz_300489.html', 'https://stock.9fzt.com/index/sz_301221.html', 'https://stock.9fzt.com/index/sz_300552.html', 'https://stock.9fzt.com/index/sh_688280.html', 'https://stock.9fzt.com/index/sz_300503.html', 'https://stock.9fzt.com/index/sz_300549.html', 'https://stock.9fzt.com/index/sh_688331.html', 'https://stock.9fzt.com/index/bj_831278.html', 'https://stock.9fzt.com/index/sh_688147.html', 'https://stock.9fzt.com/index/sh_688123.html', 'https://stock.9fzt.com/index/bj_836221.html', 'https://stock.9fzt.com/index/sh_688326.html', 'https://stock.9fzt.com/index/sz_301099.html', 'https://stock.9fzt.com/index/sh_688071.html', 'https://stock.9fzt.com/index/sz_300496.html', 'https://stock.9fzt.com/index/sz_301183.html', 'https://stock.9fzt.com/index/sz_301023.html', 'https://stock.9fzt.com/index/bj_838837.html', 'https://stock.9fzt.com/index/bj_830839.html', 'https://stock.9fzt.com/index/sh_688368.html', 'https://stock.9fzt.com/index/sz_300095.html', 'https://stock.9fzt.com/index/sz_300273.html', 'https://stock.9fzt.com/index/sz_300558.html', 'https://stock.9fzt.com/index/sz_300928.html', 'https://stock.9fzt.com/index/sz_300044.html', 'https://stock.9fzt.com/index/bj_430418.html', 'https://stock.9fzt.com/index/sz_000691.html', 'https://stock.9fzt.com/index/sh_601279.html', 'https://stock.9fzt.com/index/sh_600742.html', 'https://stock.9fzt.com/index/bj_830896.html', 'https://stock.9fzt.com/index/sz_002211.html', 'https://stock.9fzt.com/index/sz_002703.html', 'https://stock.9fzt.com/index/sz_002355.html', 'https://stock.9fzt.com/index/sh_603178.html', 'https://stock.9fzt.com/index/sz_002583.html', 'https://stock.9fzt.com/index/sz_002196.html', 'https://stock.9fzt.com/index/sh_603596.html', 'https://stock.9fzt.com/index/sh_603297.html', 'https://stock.9fzt.com/index/sh_603786.html', 'https://stock.9fzt.com/index/sz_002997.html', 'https://stock.9fzt.com/index/sh_603266.html', 'https://stock.9fzt.com/index/sh_603355.html', 'https://stock.9fzt.com/index/sh_605005.html', 'https://stock.9fzt.com/index/sz_002232.html', 'https://stock.9fzt.com/index/sz_002036.html', 'https://stock.9fzt.com/index/sz_002892.html', 'https://stock.9fzt.com/index/sh_603023.html', 'https://stock.9fzt.com/index/sh_603788.html', 'https://stock.9fzt.com/index/sz_000980.html', 'https://stock.9fzt.com/index/sz_002284.html', 'https://stock.9fzt.com/index/sz_000766.html', 'https://stock.9fzt.com/index/sh_600960.html', 'https://stock.9fzt.com/index/sh_688515.html', 'https://stock.9fzt.com/index/sz_300445.html', 'https://stock.9fzt.com/index/sz_300585.html', 'https://stock.9fzt.com/index/sh_688235.html']
# 2023-07-04 19:20:05,495 - INFO: scraping 股东研究...
# 2023-07-04 19:20:09,100 - INFO: scraping https://stock.9fzt.com/index/bj_833533.html...
# 2023-07-04 19:20:09,869 - INFO: scraping 股东研究...
# 2023-07-04 19:20:12,933 - INFO: scraping https://stock.9fzt.com/index/sz_301007.html...
# 2023-07-04 19:20:13,686 - INFO: scraping 股东研究...
# 2023-07-04 19:20:16,314 - INFO: scraping https://stock.9fzt.com/index/sz_301255.html...
# 2023-07-04 19:20:17,492 - INFO: scraping 股东研究...
# 2023-07-04 19:20:19,802 - INFO: scraping https://stock.9fzt.com/index/sz_300489.html...
# 2023-07-04 19:20:20,700 - INFO: scraping 股东研究...
# 2023-07-04 19:20:23,378 - INFO: scraping https://stock.9fzt.com/index/sz_301221.html...
# 2023-07-04 19:20:24,210 - INFO: scraping 股东研究...
# 2023-07-04 19:20:26,205 - INFO: scraping https://stock.9fzt.com/index/sz_300552.html...
# 2023-07-04 19:20:26,893 - INFO: scraping 股东研究...
# 2023-07-04 19:20:29,508 - INFO: scraping https://stock.9fzt.com/index/sh_688280.html...
# 2023-07-04 19:20:30,798 - INFO: scraping 股东研究...
# 2023-07-04 19:20:32,591 - INFO: scraping https://stock.9fzt.com/index/sz_300503.html...
# 2023-07-04 19:20:33,482 - INFO: scraping 股东研究...
# 2023-07-04 19:20:36,054 - INFO: scraping https://stock.9fzt.com/index/sz_300549.html...
# 2023-07-04 19:20:37,009 - INFO: scraping 股东研究...
# 2023-07-04 19:20:39,729 - INFO: scraping https://stock.9fzt.com/index/sh_688331.html...
# 2023-07-04 19:20:40,849 - INFO: scraping 股东研究...
# 2023-07-04 19:20:44,035 - INFO: scraping https://stock.9fzt.com/index/bj_831278.html...
# 2023-07-04 19:20:45,042 - INFO: scraping 股东研究...
# 2023-07-04 19:20:47,953 - INFO: scraping https://stock.9fzt.com/index/sh_688147.html...
# 2023-07-04 19:20:49,241 - INFO: scraping 股东研究...
# 2023-07-04 19:20:51,813 - INFO: scraping https://stock.9fzt.com/index/sh_688123.html...
# 2023-07-04 19:20:52,717 - INFO: scraping 股东研究...
# 2023-07-04 19:20:55,150 - INFO: scraping https://stock.9fzt.com/index/bj_836221.html...
# 2023-07-04 19:20:56,062 - INFO: scraping 股东研究...
# 2023-07-04 19:20:57,637 - INFO: scraping https://stock.9fzt.com/index/sh_688326.html...
# 2023-07-04 19:20:58,663 - INFO: scraping 股东研究...
# 2023-07-04 19:21:01,138 - INFO: scraping https://stock.9fzt.com/index/sz_301099.html...
# 2023-07-04 19:21:02,077 - INFO: scraping 股东研究...
# 2023-07-04 19:21:04,789 - INFO: scraping https://stock.9fzt.com/index/sh_688071.html...
# 2023-07-04 19:21:07,020 - INFO: scraping 股东研究...
# 2023-07-04 19:21:10,154 - INFO: scraping https://stock.9fzt.com/index/sz_300496.html...
# 2023-07-04 19:21:11,280 - INFO: scraping 股东研究...
# 2023-07-04 19:21:14,338 - INFO: scraping https://stock.9fzt.com/index/sz_301183.html...
# 2023-07-04 19:21:16,503 - INFO: scraping 股东研究...
# 2023-07-04 19:21:18,663 - INFO: scraping https://stock.9fzt.com/index/sz_301488.html...
# 2023-07-04 19:21:19,767 - INFO: scraping 股东研究...
# 2023-07-04 19:21:21,917 - INFO: scraping https://stock.9fzt.com/index/bj_833533.html...
# 2023-07-04 19:21:22,776 - INFO: scraping 股东研究...
# 2023-07-04 19:21:24,726 - INFO: scraping https://stock.9fzt.com/index/sz_301007.html...
# 2023-07-04 19:21:25,624 - INFO: scraping 股东研究...
# 2023-07-04 19:21:28,913 - INFO: scraping https://stock.9fzt.com/index/sz_301255.html...
# 2023-07-04 19:21:30,032 - INFO: scraping 股东研究...
# 2023-07-04 19:21:32,453 - INFO: scraping https://stock.9fzt.com/index/sz_300489.html...
# 2023-07-04 19:21:33,875 - INFO: scraping 股东研究...
# 2023-07-04 19:21:37,900 - INFO: scraping https://stock.9fzt.com/index/sz_301221.html...
# 2023-07-04 19:21:38,960 - INFO: scraping 股东研究...
# 2023-07-04 19:21:43,357 - INFO: scraping https://stock.9fzt.com/index/sz_300552.html...
# 2023-07-04 19:21:44,973 - INFO: scraping 股东研究...
# 2023-07-04 19:21:48,979 - INFO: scraping https://stock.9fzt.com/index/sh_688280.html...
# 2023-07-04 19:21:50,206 - INFO: scraping 股东研究...
# 2023-07-04 19:21:54,014 - INFO: scraping https://stock.9fzt.com/index/sz_300503.html...
# 2023-07-04 19:21:55,431 - INFO: scraping 股东研究...
# 2023-07-04 19:21:58,464 - INFO: scraping https://stock.9fzt.com/index/sz_300549.html...
# 2023-07-04 19:21:59,544 - INFO: scraping 股东研究...
# 2023-07-04 19:22:03,741 - INFO: scraping https://stock.9fzt.com/index/sh_688331.html...
# 2023-07-04 19:22:04,965 - INFO: scraping 股东研究...
# 2023-07-04 19:22:08,642 - INFO: scraping https://stock.9fzt.com/index/bj_831278.html...
# 2023-07-04 19:22:09,977 - INFO: scraping 股东研究...
# 2023-07-04 19:22:12,591 - INFO: scraping https://stock.9fzt.com/index/sh_688147.html...
# 2023-07-04 19:22:13,731 - INFO: scraping 股东研究...
# 2023-07-04 19:22:17,292 - INFO: scraping https://stock.9fzt.com/index/sh_688123.html...
# 2023-07-04 19:22:18,247 - INFO: scraping 股东研究...
# 2023-07-04 19:22:21,851 - INFO: scraping https://stock.9fzt.com/index/bj_836221.html...
# 2023-07-04 19:22:22,744 - INFO: scraping 股东研究...
# 2023-07-04 19:22:26,669 - INFO: scraping https://stock.9fzt.com/index/sh_688326.html...
# 2023-07-04 19:22:27,677 - INFO: scraping 股东研究...
# 2023-07-04 19:22:31,562 - INFO: scraping https://stock.9fzt.com/index/sz_301099.html...
# 2023-07-04 19:22:32,524 - INFO: scraping 股东研究...
# 2023-07-04 19:22:35,770 - INFO: scraping https://stock.9fzt.com/index/sh_688071.html...
# 2023-07-04 19:22:36,800 - INFO: scraping 股东研究...
# 2023-07-04 19:22:41,000 - INFO: scraping https://stock.9fzt.com/index/sz_300496.html...
# 2023-07-04 19:22:42,085 - INFO: scraping 股东研究...
# 2023-07-04 19:22:45,897 - INFO: scraping https://stock.9fzt.com/index/sz_301183.html...
# 2023-07-04 19:22:46,904 - INFO: scraping 股东研究...
# 2023-07-04 19:22:49,855 - INFO: scraping https://stock.9fzt.com/index/sz_301023.html...
# 2023-07-04 19:22:50,941 - INFO: scraping 股东研究...
# 2023-07-04 19:22:54,692 - INFO: scraping https://stock.9fzt.com/index/bj_838837.html...
# 2023-07-04 19:22:55,875 - INFO: scraping 股东研究...
# 2023-07-04 19:22:58,918 - INFO: scraping https://stock.9fzt.com/index/bj_830839.html...
# 2023-07-04 19:23:00,151 - INFO: scraping 股东研究...
# 2023-07-04 19:23:03,358 - INFO: scraping https://stock.9fzt.com/index/sh_688368.html...
# 2023-07-04 19:23:04,410 - INFO: scraping 股东研究...
# 2023-07-04 19:23:08,086 - INFO: scraping https://stock.9fzt.com/index/sz_300095.html...
# 2023-07-04 19:23:09,472 - INFO: scraping 股东研究...
# 2023-07-04 19:23:12,843 - INFO: scraping https://stock.9fzt.com/index/sz_300273.html...
# 2023-07-04 19:23:13,960 - INFO: scraping 股东研究...
# 2023-07-04 19:23:17,617 - INFO: scraping https://stock.9fzt.com/index/sz_300558.html...
# 2023-07-04 19:23:18,831 - INFO: scraping 股东研究...
# 2023-07-04 19:23:23,966 - INFO: scraping https://stock.9fzt.com/index/sz_300928.html...
# 2023-07-04 19:23:26,866 - INFO: scraping 股东研究...
# 2023-07-04 19:23:32,763 - INFO: scraping https://stock.9fzt.com/index/sz_300044.html...
# 2023-07-04 19:23:34,687 - INFO: scraping 股东研究...
# 2023-07-04 19:23:39,682 - INFO: scraping https://stock.9fzt.com/index/bj_430418.html...
# 2023-07-04 19:23:41,155 - INFO: scraping 股东研究...
# 2023-07-04 19:23:44,792 - INFO: scraping https://stock.9fzt.com/index/sz_000691.html...
# 2023-07-04 19:23:46,781 - INFO: scraping 股东研究...
# 2023-07-04 19:23:49,541 - INFO: scraping https://stock.9fzt.com/index/sh_601279.html...
# 2023-07-04 19:23:50,892 - INFO: scraping 股东研究...
# 2023-07-04 19:23:56,224 - INFO: scraping https://stock.9fzt.com/index/sh_600742.html...
# 2023-07-04 19:23:57,734 - INFO: scraping 股东研究...
# 2023-07-04 19:24:03,454 - INFO: scraping https://stock.9fzt.com/index/bj_830896.html...
# 2023-07-04 19:24:05,204 - INFO: scraping 股东研究...
# 2023-07-04 19:24:09,418 - INFO: scraping https://stock.9fzt.com/index/sz_002211.html...
# 2023-07-04 19:24:11,321 - INFO: scraping 股东研究...
# 2023-07-04 19:24:17,816 - INFO: scraping https://stock.9fzt.com/index/sz_002703.html...
# 2023-07-04 19:24:18,996 - INFO: scraping 股东研究...
# 2023-07-04 19:24:22,826 - INFO: scraping https://stock.9fzt.com/index/sz_002355.html...
# 2023-07-04 19:24:24,384 - INFO: scraping 股东研究...
# 2023-07-04 19:24:28,604 - INFO: scraping https://stock.9fzt.com/index/sh_603178.html...
# 2023-07-04 19:24:30,079 - INFO: scraping 股东研究...
# 2023-07-04 19:24:34,879 - INFO: scraping https://stock.9fzt.com/index/sz_002583.html...
# 2023-07-04 19:24:36,355 - INFO: scraping 股东研究...
# 2023-07-04 19:24:43,804 - INFO: scraping https://stock.9fzt.com/index/sz_002196.html...
# 2023-07-04 19:24:44,994 - INFO: scraping 股东研究...
# 2023-07-04 19:24:49,725 - INFO: scraping https://stock.9fzt.com/index/sh_603596.html...
# 2023-07-04 19:24:51,671 - INFO: scraping 股东研究...
# 2023-07-04 19:24:58,959 - INFO: scraping https://stock.9fzt.com/index/sh_603297.html...
# 2023-07-04 19:25:00,933 - INFO: scraping 股东研究...
# 2023-07-04 19:25:06,918 - INFO: scraping https://stock.9fzt.com/index/sh_603786.html...
# 2023-07-04 19:25:08,552 - INFO: scraping 股东研究...
# 2023-07-04 19:25:16,541 - INFO: scraping https://stock.9fzt.com/index/sz_002997.html...
# 2023-07-04 19:25:18,690 - INFO: scraping 股东研究...
# 2023-07-04 19:25:25,101 - INFO: scraping https://stock.9fzt.com/index/sh_603266.html...
# 2023-07-04 19:25:27,914 - INFO: scraping 股东研究...
# 2023-07-04 19:25:34,485 - INFO: scraping https://stock.9fzt.com/index/sh_603355.html...
# 2023-07-04 19:25:36,145 - INFO: scraping 股东研究...
# 2023-07-04 19:25:43,051 - INFO: scraping https://stock.9fzt.com/index/sh_605005.html...
# 2023-07-04 19:25:45,456 - INFO: scraping 股东研究...
# 2023-07-04 19:25:50,541 - INFO: scraping https://stock.9fzt.com/index/sz_002232.html...
# 2023-07-04 19:25:52,911 - INFO: scraping 股东研究...
# 2023-07-04 19:25:58,486 - INFO: scraping https://stock.9fzt.com/index/sz_002036.html...
# 2023-07-04 19:26:00,247 - INFO: scraping 股东研究...
# 2023-07-04 19:26:05,910 - INFO: scraping https://stock.9fzt.com/index/sz_002892.html...
# 2023-07-04 19:26:07,577 - INFO: scraping 股东研究...
# 2023-07-04 19:26:13,019 - INFO: scraping https://stock.9fzt.com/index/sh_603023.html...
# 2023-07-04 19:26:15,438 - INFO: scraping 股东研究...
# 2023-07-04 19:26:20,328 - INFO: scraping https://stock.9fzt.com/index/sh_603788.html...
# 2023-07-04 19:26:22,160 - INFO: scraping 股东研究...
# 2023-07-04 19:26:27,102 - INFO: scraping https://stock.9fzt.com/index/sz_000980.html...
# 2023-07-04 19:26:28,811 - INFO: scraping 股东研究...
# 2023-07-04 19:26:34,352 - INFO: scraping https://stock.9fzt.com/index/sz_002284.html...
# 2023-07-04 19:26:36,370 - INFO: scraping 股东研究...
# 2023-07-04 19:26:41,171 - INFO: scraping https://stock.9fzt.com/index/sz_000766.html...
# 2023-07-04 19:26:43,327 - INFO: scraping 股东研究...
# 2023-07-04 19:26:48,668 - INFO: scraping https://stock.9fzt.com/index/sh_600960.html...
# 2023-07-04 19:26:50,535 - INFO: scraping 股东研究...
# 2023-07-04 19:26:55,502 - INFO: scraping https://stock.9fzt.com/index/sh_688515.html...
# 2023-07-04 19:26:57,264 - INFO: scraping 股东研究...
# 2023-07-04 19:27:01,789 - INFO: scraping https://stock.9fzt.com/index/sz_300445.html...
# 2023-07-04 19:27:03,495 - INFO: scraping 股东研究...
# 2023-07-04 19:27:07,702 - INFO: scraping https://stock.9fzt.com/index/sz_300585.html...
# 2023-07-04 19:27:09,636 - INFO: scraping 股东研究...
# 2023-07-04 19:27:14,379 - INFO: scraping https://stock.9fzt.com/index/sh_688235.html...
# 2023-07-04 19:27:16,317 - INFO: scraping 股东研究...
