# %%
import logging
import re
from urllib.parse import urljoin,urlencode
import multiprocessing
import time
import json
from os import makedirs
from os.path import exists
import pandas as pd
from lxml import etree

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ChromeOptions

logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(levelname)s: %(message)s')

# 基础网址和爬取页码数量设定
BASE_URL='https://www.9fzt.com/marketCenter/aStockMarket.html?tab=0'
TOT_PAGEs=3

# %%
# %%
def get_browser():
    option=ChromeOptions()
    option.add_experimental_option('excludeSwitches',['enable-automation'])
    option.add_experimental_option('useAutomationExtension',False)
    # 设置不显式地显示浏览器
    option.add_argument('--headless')
    browser=webdriver.Chrome(options=option)
    browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument",
                            {'source': 'Object.defineProperty(navigator,"webdriver",{get:()=>undefind})'})
    browser.implicitly_wait(10)
    return browser

# %%
def parse_page(page_html,protol_type='https:'):
    pattern=re.compile('序号(.*)',re.S)
    stock_urls=re.findall(pattern,page_html)
    pattern=re.compile('<a href="(.*?)".*? class="bluelink ff_din-medium fw-500" target="_blank" rel="noopener">',re.S)
    stock_urls=re.findall(pattern,str(stock_urls))
    stock_urls=[urljoin(protol_type,url) for url in stock_urls]
    return stock_urls

# %%
# %%
def scrape_stock_list(browser,page_num):
    browser.get(BASE_URL)
    urls=[]
    WebDriverWait(browser,20,0.5).until(lambda browser:len(
        browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    for page in range(page_num):
        urls+=(parse_page(browser.page_source))
        time.sleep(0.1)
        ac=ActionChains(browser)
        # 鼠标移动到下一页按钮上
        ac.move_to_element(browser.find_element_by_name('whj_nextPage')).perform()
        # 点击确定跳转至下一页
        ac.click(browser.find_element_by_name('whj_nextPage')).perform()
        time.sleep(0.1)
        WebDriverWait(browser,10,0.5).until(lambda browser: len(
            browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    print(urls)
    return urls

# %%
# %%
def scrape_stockprice_page(browser,url):
    logging.info('scraping %s...',url)
    browser.get(url)
    WebDriverWait(browser,60,2).until(lambda browser: browser.find_element_by_id('stockprice').text != '--')
    return browser.page_source

# %%
# %%
def scrape_company_list(browser,urls):
    companys=[]
    for url in urls:
        logging.info('scraping %s...',url)
        browser.get(url)
        logging.info('scraping 最新动态...')
        browser.find_element_by_link_text('最新动态').click()
        browser.switch_to.window(browser.window_handles[1])
        WebDriverWait(browser,10,2).until(lambda browser: len(
           browser.find_element(By.XPATH,'//*[@id="gsgy"]/div[2]/div/div/section/div/ul/li[2]/div[2]/div/span').text)>0)
        shareholder=browser.page_source
        browser.close()
        browser.switch_to.window(browser.window_handles[0])
        #shareholder = None

        companys.append([shareholder])
    return companys

# %%
# 使用xpath匹配
concept_xpath='//*[@id="gsgy"]/div[2]/div/div/section/div/ul/li[2]/div[2]/div/span/text()'

def parse_company_data(html):
    html=etree.HTML(html)
    
    concept=html.xpath(concept_xpath)[0]

    return [concept]

# %%
# %%
def get_table_company_data(data):
    table=pd.DataFrame(columns=['concept'])
    for item in data:
        table.loc[len(table)]=parse_company_data(item)
    return table

# %%
# %%
browser=get_browser()
urls=scrape_stock_list(browser,TOT_PAGEs)
#urls=['https://stock.9fzt.com/index/bj_870204.html']

companys=scrape_company_list(browser,urls)
data=[company[0] for company in companys]

company_data_table=get_table_company_data(data)
#print(company_data_table)

company_data_table.to_csv('concept_data_table.csv',index=False,encoding='gbk')

# TO-DO 其他可以保存的数据信息
# price_table = get_table_price(browser, urls)
# price_table.to_csv('price_table.csv', index=False)
# Out:
# 2023-07-04 15:51:45,512 - INFO: scraping https://stock.9fzt.com/index/sz_301488.html...
# ['https://stock.9fzt.com/index/sz_301488.html', 'https://stock.9fzt.com/index/bj_833533.html', 'https://stock.9fzt.com/index/sz_301007.html', 'https://stock.9fzt.com/index/sz_301255.html', 'https://stock.9fzt.com/index/sz_300489.html', 'https://stock.9fzt.com/index/sz_301221.html', 'https://stock.9fzt.com/index/sz_300552.html', 'https://stock.9fzt.com/index/sh_688280.html', 'https://stock.9fzt.com/index/sz_300503.html', 'https://stock.9fzt.com/index/sz_300549.html', 'https://stock.9fzt.com/index/sh_688331.html', 'https://stock.9fzt.com/index/bj_831278.html', 'https://stock.9fzt.com/index/sh_688147.html', 'https://stock.9fzt.com/index/sh_688123.html', 'https://stock.9fzt.com/index/bj_836221.html', 'https://stock.9fzt.com/index/sh_688326.html', 'https://stock.9fzt.com/index/sz_301099.html', 'https://stock.9fzt.com/index/sh_688071.html', 'https://stock.9fzt.com/index/sz_300496.html', 'https://stock.9fzt.com/index/sz_301183.html', 'https://stock.9fzt.com/index/sz_301023.html', 'https://stock.9fzt.com/index/bj_838837.html', 'https://stock.9fzt.com/index/bj_830839.html', 'https://stock.9fzt.com/index/sh_688368.html', 'https://stock.9fzt.com/index/sz_300095.html', 'https://stock.9fzt.com/index/sz_300273.html', 'https://stock.9fzt.com/index/sz_300558.html', 'https://stock.9fzt.com/index/sz_300928.html', 'https://stock.9fzt.com/index/sz_300044.html', 'https://stock.9fzt.com/index/bj_430418.html', 'https://stock.9fzt.com/index/sz_000691.html', 'https://stock.9fzt.com/index/sh_601279.html', 'https://stock.9fzt.com/index/sh_600742.html', 'https://stock.9fzt.com/index/bj_830896.html', 'https://stock.9fzt.com/index/sz_002211.html', 'https://stock.9fzt.com/index/sz_002703.html', 'https://stock.9fzt.com/index/sz_002355.html', 'https://stock.9fzt.com/index/sh_603178.html', 'https://stock.9fzt.com/index/sz_002583.html', 'https://stock.9fzt.com/index/sz_002196.html', 'https://stock.9fzt.com/index/sz_301023.html', 'https://stock.9fzt.com/index/bj_838837.html', 'https://stock.9fzt.com/index/bj_830839.html', 'https://stock.9fzt.com/index/sh_688368.html', 'https://stock.9fzt.com/index/sz_300095.html', 'https://stock.9fzt.com/index/sz_300273.html', 'https://stock.9fzt.com/index/sz_300558.html', 'https://stock.9fzt.com/index/sz_300928.html', 'https://stock.9fzt.com/index/sz_300044.html', 'https://stock.9fzt.com/index/bj_430418.html', 'https://stock.9fzt.com/index/sz_000691.html', 'https://stock.9fzt.com/index/sh_601279.html', 'https://stock.9fzt.com/index/sh_600742.html', 'https://stock.9fzt.com/index/bj_830896.html', 'https://stock.9fzt.com/index/sz_002211.html', 'https://stock.9fzt.com/index/sz_002703.html', 'https://stock.9fzt.com/index/sz_002355.html', 'https://stock.9fzt.com/index/sh_603178.html', 'https://stock.9fzt.com/index/sz_002583.html', 'https://stock.9fzt.com/index/sz_002196.html']
# 2023-07-04 15:51:46,939 - INFO: scraping 最新动态...
# 2023-07-04 15:51:49,443 - INFO: scraping https://stock.9fzt.com/index/bj_833533.html...
# 2023-07-04 15:51:50,250 - INFO: scraping 最新动态...
# 2023-07-04 15:51:52,128 - INFO: scraping https://stock.9fzt.com/index/sz_301007.html...
# 2023-07-04 15:51:52,789 - INFO: scraping 最新动态...
# 2023-07-04 15:51:54,608 - INFO: scraping https://stock.9fzt.com/index/sz_301255.html...
# 2023-07-04 15:51:55,173 - INFO: scraping 最新动态...
# 2023-07-04 15:51:56,539 - INFO: scraping https://stock.9fzt.com/index/sz_300489.html...
# 2023-07-04 15:51:57,489 - INFO: scraping 最新动态...
# 2023-07-04 15:51:59,242 - INFO: scraping https://stock.9fzt.com/index/sz_301221.html...
# 2023-07-04 15:52:00,145 - INFO: scraping 最新动态...
# 2023-07-04 15:52:01,807 - INFO: scraping https://stock.9fzt.com/index/sz_300552.html...
# 2023-07-04 15:52:02,582 - INFO: scraping 最新动态...
# 2023-07-04 15:52:04,428 - INFO: scraping https://stock.9fzt.com/index/sh_688280.html...
# 2023-07-04 15:52:05,103 - INFO: scraping 最新动态...
# 2023-07-04 15:52:06,948 - INFO: scraping https://stock.9fzt.com/index/sz_300503.html...
# 2023-07-04 15:52:07,618 - INFO: scraping 最新动态...
# 2023-07-04 15:52:09,162 - INFO: scraping https://stock.9fzt.com/index/sz_300549.html...
# 2023-07-04 15:52:09,825 - INFO: scraping 最新动态...
# 2023-07-04 15:52:11,675 - INFO: scraping https://stock.9fzt.com/index/sh_688331.html...
# 2023-07-04 15:52:12,340 - INFO: scraping 最新动态...
# 2023-07-04 15:52:14,299 - INFO: scraping https://stock.9fzt.com/index/bj_831278.html...
# 2023-07-04 15:52:15,139 - INFO: scraping 最新动态...
# 2023-07-04 15:52:16,921 - INFO: scraping https://stock.9fzt.com/index/sh_688147.html...
# 2023-07-04 15:52:17,736 - INFO: scraping 最新动态...
# 2023-07-04 15:52:19,418 - INFO: scraping https://stock.9fzt.com/index/sh_688123.html...
# 2023-07-04 15:52:20,087 - INFO: scraping 最新动态...
# 2023-07-04 15:52:22,064 - INFO: scraping https://stock.9fzt.com/index/bj_836221.html...
# 2023-07-04 15:52:22,668 - INFO: scraping 最新动态...
# 2023-07-04 15:52:23,873 - INFO: scraping https://stock.9fzt.com/index/sh_688326.html...
# 2023-07-04 15:52:24,493 - INFO: scraping 最新动态...
# 2023-07-04 15:52:26,277 - INFO: scraping https://stock.9fzt.com/index/sz_301099.html...
# 2023-07-04 15:52:26,971 - INFO: scraping 最新动态...
# 2023-07-04 15:52:29,110 - INFO: scraping https://stock.9fzt.com/index/sh_688071.html...
# 2023-07-04 15:52:30,161 - INFO: scraping 最新动态...
# 2023-07-04 15:52:32,553 - INFO: scraping https://stock.9fzt.com/index/sz_300496.html...
# 2023-07-04 15:52:33,294 - INFO: scraping 最新动态...
# 2023-07-04 15:52:34,834 - INFO: scraping https://stock.9fzt.com/index/sz_301183.html...
# 2023-07-04 15:52:35,359 - INFO: scraping 最新动态...
# 2023-07-04 15:52:37,320 - INFO: scraping https://stock.9fzt.com/index/sz_301023.html...
# 2023-07-04 15:52:37,973 - INFO: scraping 最新动态...
# 2023-07-04 15:52:39,571 - INFO: scraping https://stock.9fzt.com/index/bj_838837.html...
# 2023-07-04 15:52:40,256 - INFO: scraping 最新动态...
# 2023-07-04 15:52:41,726 - INFO: scraping https://stock.9fzt.com/index/bj_830839.html...
# 2023-07-04 15:52:42,339 - INFO: scraping 最新动态...
# 2023-07-04 15:52:43,751 - INFO: scraping https://stock.9fzt.com/index/sh_688368.html...
# 2023-07-04 15:52:44,509 - INFO: scraping 最新动态...
# 2023-07-04 15:52:46,943 - INFO: scraping https://stock.9fzt.com/index/sz_300095.html...
# 2023-07-04 15:52:47,577 - INFO: scraping 最新动态...
# 2023-07-04 15:52:49,542 - INFO: scraping https://stock.9fzt.com/index/sz_300273.html...
# 2023-07-04 15:52:50,153 - INFO: scraping 最新动态...
# 2023-07-04 15:52:52,373 - INFO: scraping https://stock.9fzt.com/index/sz_300558.html...
# 2023-07-04 15:52:53,153 - INFO: scraping 最新动态...
# 2023-07-04 15:52:55,568 - INFO: scraping https://stock.9fzt.com/index/sz_300928.html...
# 2023-07-04 15:52:56,517 - INFO: scraping 最新动态...
# 2023-07-04 15:52:58,916 - INFO: scraping https://stock.9fzt.com/index/sz_300044.html...
# 2023-07-04 15:52:59,773 - INFO: scraping 最新动态...
# 2023-07-04 15:53:01,859 - INFO: scraping https://stock.9fzt.com/index/bj_430418.html...
# 2023-07-04 15:53:03,432 - INFO: scraping 最新动态...
# 2023-07-04 15:53:05,057 - INFO: scraping https://stock.9fzt.com/index/sz_000691.html...
# 2023-07-04 15:53:05,810 - INFO: scraping 最新动态...
# 2023-07-04 15:53:07,511 - INFO: scraping https://stock.9fzt.com/index/sh_601279.html...
# 2023-07-04 15:53:08,324 - INFO: scraping 最新动态...
# 2023-07-04 15:53:09,926 - INFO: scraping https://stock.9fzt.com/index/sh_600742.html...
# 2023-07-04 15:53:10,494 - INFO: scraping 最新动态...
# 2023-07-04 15:53:12,204 - INFO: scraping https://stock.9fzt.com/index/bj_830896.html...
# 2023-07-04 15:53:12,804 - INFO: scraping 最新动态...
# 2023-07-04 15:53:13,890 - INFO: scraping https://stock.9fzt.com/index/sz_002211.html...
# 2023-07-04 15:53:14,613 - INFO: scraping 最新动态...
# 2023-07-04 15:53:16,519 - INFO: scraping https://stock.9fzt.com/index/sz_002703.html...
# 2023-07-04 15:53:17,244 - INFO: scraping 最新动态...
# 2023-07-04 15:53:18,972 - INFO: scraping https://stock.9fzt.com/index/sz_002355.html...
# 2023-07-04 15:53:19,583 - INFO: scraping 最新动态...
# 2023-07-04 15:53:21,598 - INFO: scraping https://stock.9fzt.com/index/sh_603178.html...
# 2023-07-04 15:53:22,469 - INFO: scraping 最新动态...
# 2023-07-04 15:53:24,133 - INFO: scraping https://stock.9fzt.com/index/sz_002583.html...
# 2023-07-04 15:53:24,859 - INFO: scraping 最新动态...
# 2023-07-04 15:53:26,532 - INFO: scraping https://stock.9fzt.com/index/sz_002196.html...
# 2023-07-04 15:53:27,429 - INFO: scraping 最新动态...
# 2023-07-04 15:53:29,753 - INFO: scraping https://stock.9fzt.com/index/sz_301023.html...
# 2023-07-04 15:53:30,527 - INFO: scraping 最新动态...
# 2023-07-04 15:53:31,765 - INFO: scraping https://stock.9fzt.com/index/bj_838837.html...
# 2023-07-04 15:53:32,492 - INFO: scraping 最新动态...
# 2023-07-04 15:53:33,853 - INFO: scraping https://stock.9fzt.com/index/bj_830839.html...
# 2023-07-04 15:53:34,517 - INFO: scraping 最新动态...
# 2023-07-04 15:53:35,844 - INFO: scraping https://stock.9fzt.com/index/sh_688368.html...
# 2023-07-04 15:53:36,530 - INFO: scraping 最新动态...
# 2023-07-04 15:53:38,327 - INFO: scraping https://stock.9fzt.com/index/sz_300095.html...
# 2023-07-04 15:53:39,066 - INFO: scraping 最新动态...
# 2023-07-04 15:53:40,549 - INFO: scraping https://stock.9fzt.com/index/sz_300273.html...
# 2023-07-04 15:53:41,228 - INFO: scraping 最新动态...
# 2023-07-04 15:53:42,433 - INFO: scraping https://stock.9fzt.com/index/sz_300558.html...
# 2023-07-04 15:53:43,114 - INFO: scraping 最新动态...
# 2023-07-04 15:53:44,574 - INFO: scraping https://stock.9fzt.com/index/sz_300928.html...
# 2023-07-04 15:53:45,146 - INFO: scraping 最新动态...
# 2023-07-04 15:53:46,224 - INFO: scraping https://stock.9fzt.com/index/sz_300044.html...
# 2023-07-04 15:53:47,112 - INFO: scraping 最新动态...
# 2023-07-04 15:53:48,836 - INFO: scraping https://stock.9fzt.com/index/bj_430418.html...
# 2023-07-04 15:53:49,532 - INFO: scraping 最新动态...
# 2023-07-04 15:53:50,710 - INFO: scraping https://stock.9fzt.com/index/sz_000691.html...
# 2023-07-04 15:53:51,322 - INFO: scraping 最新动态...
# 2023-07-04 15:53:53,021 - INFO: scraping https://stock.9fzt.com/index/sh_601279.html...
# 2023-07-04 15:53:53,711 - INFO: scraping 最新动态...
# 2023-07-04 15:53:55,151 - INFO: scraping https://stock.9fzt.com/index/sh_600742.html...
# 2023-07-04 15:53:55,778 - INFO: scraping 最新动态...
# 2023-07-04 15:53:56,920 - INFO: scraping https://stock.9fzt.com/index/bj_830896.html...
# 2023-07-04 15:53:57,568 - INFO: scraping 最新动态...
# 2023-07-04 15:53:58,590 - INFO: scraping https://stock.9fzt.com/index/sz_002211.html...
# 2023-07-04 15:53:59,259 - INFO: scraping 最新动态...
# 2023-07-04 15:54:00,392 - INFO: scraping https://stock.9fzt.com/index/sz_002703.html...
# 2023-07-04 15:54:01,123 - INFO: scraping 最新动态...
# 2023-07-04 15:54:02,251 - INFO: scraping https://stock.9fzt.com/index/sz_002355.html...
# 2023-07-04 15:54:02,895 - INFO: scraping 最新动态...
# 2023-07-04 15:54:04,764 - INFO: scraping https://stock.9fzt.com/index/sh_603178.html...
# 2023-07-04 15:54:05,419 - INFO: scraping 最新动态...
# 2023-07-04 15:54:06,805 - INFO: scraping https://stock.9fzt.com/index/sz_002583.html...
# 2023-07-04 15:54:08,402 - INFO: scraping 最新动态...
# 2023-07-04 15:54:09,445 - INFO: scraping https://stock.9fzt.com/index/sz_002196.html...
# 2023-07-04 15:54:10,041 - INFO: scraping 最新动态...
