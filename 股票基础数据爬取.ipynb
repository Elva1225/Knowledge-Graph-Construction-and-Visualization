# %%
import logging
import re
from urllib.parse import urljoin,urlencode
import multiprocessing
import time
import json
from os import makedirs
from os.path import exists
import pandas as pd
from lxml import etree

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ChromeOptions

logging.basicConfig(level=logging.INFO,format='%(asctime)s - %(levelname)s: %(message)s')

# 基础网址和爬取页码数量设定
BASE_URL='https://www.9fzt.com/marketCenter/aStockMarket.html?tab=0'
TOT_PAGEs=3

# %%
# %%
def get_browser():
    option=ChromeOptions()
    option.add_experimental_option('excludeSwitches',['enable-automation'])
    option.add_experimental_option('useAutomationExtension',False)
    # 设置不显式地显示浏览器
    option.add_argument('--headless')
    browser=webdriver.Chrome(options=option)
    browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument",
                            {'source': 'Object.defineProperty(navigator,"webdriver",{get:()=>undefind})'})
    browser.implicitly_wait(10)
    return browser

# %%
# %%
# 正则表达式测试地址：http://tool.oschina.net/regex/
def parse_page(page_html,protol_type='https:'):
    pattern=re.compile('序号(.*)',re.S)
    stock_urls=re.findall(pattern,page_html)
    pattern=re.compile('<a href="(.*?)".*? class="bluelink ff_din-medium fw-500" target="_blank" rel="noopener">',re.S)
    stock_urls=re.findall(pattern,str(stock_urls))
    stock_urls=[urljoin(protol_type,url) for url in stock_urls]
    return stock_urls

# %%
# %%
def scrape_stock_list(browser,page_num):
    browser.get(BASE_URL)
    urls=[]
    WebDriverWait(browser,20,0.5).until(lambda browser:len(
        browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    for page in range(page_num):
        urls+=(parse_page(browser.page_source))
        time.sleep(0.1)
        ac=ActionChains(browser)
        # 鼠标移动到下一页按钮上
        ac.move_to_element(browser.find_element_by_name('whj_nextPage')).perform()
        # 点击确定跳转至下一页
        ac.click(browser.find_element_by_name('whj_nextPage')).perform()
        time.sleep(0.1)
        WebDriverWait(browser,10,0.5).until(lambda browser: len(
            browser.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/div[2]/ul[20]/li[13]/span').text)>0)
    print(urls)
    return urls

# %%
# %%
def scrape_stockprice_page(browser,url):
    logging.info('scraping %s...',url)
    browser.get(url)
    WebDriverWait(browser,60,2).until(lambda browser: browser.find_element_by_id('stockprice').text != '--')
    return browser.page_source

# %%
# %%
def scrape_company_list(browser,urls):
    companys=[]
    for url in urls:
        logging.info('scraping %s...',url)
        browser.get(url)

        logging.info('scraping 公司资料...')
        browser.find_element_by_link_text('公司资料').click()
        browser.switch_to.window(browser.window_handles[1])
        WebDriverWait(browser,10,2).until(lambda browser: len(
            browser.find_element(By.XPATH,'//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[4]/div[2]/section/div/div').text)>5)
        data=browser.page_source
        browser.close()
        browser.switch_to.window(browser.window_handles[0])
        
        shareholder = None

        companys.append([data,shareholder])
    return companys

# %%
# 使用xpath匹配
stock_code_name_xpath='//*[@id="app"]/div/section/div[1]/section/div[1]/div/div/div[1]/h3/i/text()'
company_name_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[1]/div[2]/div/span/text()'
company_time_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[5]/div[2]/div/span/text()'
company_business_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[23]/div[2]/div/span/text()'
company_representative_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[9]/div[2]/div/span/text()'
company_manager_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[10]/div[2]/div/span/text()'
company_secretary_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[11]/div[2]/div/span/text()'
company_phone_xpath='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[14]/div[2]/div/span/text()'
company_place_pattern='//*[@id="xxqk"]/div[2]/div/div/section/div/ul/li[18]/div[2]/div/span/text()'

# 使用re匹配
city_pattern=re.compile('(.*?省)?(.*?市)?',re.S)


def parse_company_data(html):
    html=etree.HTML(html)

    code_name = html.xpath(stock_code_name_xpath)[0].split(' ')
    stock_code = code_name[0]
    stock_name = code_name[1]

    company_place=html.xpath(company_place_pattern)[0]

    province='--'
    city='--'
    if re.search(city_pattern,company_place).group(1):
        province=re.search(city_pattern,company_place).group(1)
    if re.search(city_pattern,company_place).group(2):
        city=re.search(city_pattern,company_place).group(2)

    company_name=html.xpath(company_name_xpath)[0]
    company_time=html.xpath(company_time_xpath)[0]
    company_business=html.xpath(company_business_xpath)[0]
    company_representative=html.xpath(company_representative_xpath)[0]
    company_manager=html.xpath(company_manager_xpath)[0]
    company_secretary=html.xpath(company_secretary_xpath)[0]
    company_phone=html.xpath(company_phone_xpath)[0]

    return [stock_code,stock_name,company_name,province,city,company_time,company_business,company_representative,
            company_manager,company_secretary,company_phone]

# %%
# %%
def get_table_company_data(data):
    table=pd.DataFrame(columns=['stock_code','stock_name','company_name','province','city',
                                'company_time','company_business','company_representative',
                                'company_manager','company_secretary','company_phone'])
    for item in data:
        table.loc[len(table)]=parse_company_data(item)
    return table

# %%
# %%
browser=get_browser()
urls=scrape_stock_list(browser,TOT_PAGEs)
# urls=['https://stock.9fzt.com/index/bj_870204.html']

companys=scrape_company_list(browser,urls)
data=[company[0] for company in companys]

company_data_table=get_table_company_data(data)
company_data_table.to_csv('company_data_table.csv',index=False,encoding='gbk')
# Out:
# 2023-07-04 19:00:51,078 - INFO: scraping https://stock.9fzt.com/index/sz_301488.html...
# ['https://stock.9fzt.com/index/sz_301488.html', 'https://stock.9fzt.com/index/bj_833533.html', 'https://stock.9fzt.com/index/sz_301007.html', 'https://stock.9fzt.com/index/sz_301255.html', 'https://stock.9fzt.com/index/sz_300489.html', 'https://stock.9fzt.com/index/sz_301221.html', 'https://stock.9fzt.com/index/sz_300552.html', 'https://stock.9fzt.com/index/sh_688280.html', 'https://stock.9fzt.com/index/sz_300503.html', 'https://stock.9fzt.com/index/sz_300549.html', 'https://stock.9fzt.com/index/sh_688331.html', 'https://stock.9fzt.com/index/bj_831278.html', 'https://stock.9fzt.com/index/sh_688147.html', 'https://stock.9fzt.com/index/sh_688123.html', 'https://stock.9fzt.com/index/bj_836221.html', 'https://stock.9fzt.com/index/sh_688326.html', 'https://stock.9fzt.com/index/sz_301099.html', 'https://stock.9fzt.com/index/sh_688071.html', 'https://stock.9fzt.com/index/sz_300496.html', 'https://stock.9fzt.com/index/sz_301183.html', 'https://stock.9fzt.com/index/sz_301488.html', 'https://stock.9fzt.com/index/bj_833533.html', 'https://stock.9fzt.com/index/sz_301007.html', 'https://stock.9fzt.com/index/sz_301255.html', 'https://stock.9fzt.com/index/sz_300489.html', 'https://stock.9fzt.com/index/sz_301221.html', 'https://stock.9fzt.com/index/sz_300552.html', 'https://stock.9fzt.com/index/sh_688280.html', 'https://stock.9fzt.com/index/sz_300503.html', 'https://stock.9fzt.com/index/sz_300549.html', 'https://stock.9fzt.com/index/sh_688331.html', 'https://stock.9fzt.com/index/bj_831278.html', 'https://stock.9fzt.com/index/sh_688147.html', 'https://stock.9fzt.com/index/sh_688123.html', 'https://stock.9fzt.com/index/bj_836221.html', 'https://stock.9fzt.com/index/sh_688326.html', 'https://stock.9fzt.com/index/sz_301099.html', 'https://stock.9fzt.com/index/sh_688071.html', 'https://stock.9fzt.com/index/sz_300496.html', 'https://stock.9fzt.com/index/sz_301183.html', 'https://stock.9fzt.com/index/sz_301023.html', 'https://stock.9fzt.com/index/bj_838837.html', 'https://stock.9fzt.com/index/bj_830839.html', 'https://stock.9fzt.com/index/sh_688368.html', 'https://stock.9fzt.com/index/sz_300095.html', 'https://stock.9fzt.com/index/sz_300273.html', 'https://stock.9fzt.com/index/sz_300558.html', 'https://stock.9fzt.com/index/sz_300928.html', 'https://stock.9fzt.com/index/sz_300044.html', 'https://stock.9fzt.com/index/bj_430418.html', 'https://stock.9fzt.com/index/sz_000691.html', 'https://stock.9fzt.com/index/sh_601279.html', 'https://stock.9fzt.com/index/sh_600742.html', 'https://stock.9fzt.com/index/bj_830896.html', 'https://stock.9fzt.com/index/sz_002211.html', 'https://stock.9fzt.com/index/sz_002703.html', 'https://stock.9fzt.com/index/sz_002355.html', 'https://stock.9fzt.com/index/sh_603178.html', 'https://stock.9fzt.com/index/sz_002583.html', 'https://stock.9fzt.com/index/sz_002196.html', 'https://stock.9fzt.com/index/sh_603037.html', 'https://stock.9fzt.com/index/sz_000020.html', 'https://stock.9fzt.com/index/sh_603015.html', 'https://stock.9fzt.com/index/sh_603045.html', 'https://stock.9fzt.com/index/sh_603085.html', 'https://stock.9fzt.com/index/sz_002403.html', 'https://stock.9fzt.com/index/sz_301052.html', 'https://stock.9fzt.com/index/sz_002976.html', 'https://stock.9fzt.com/index/sz_002653.html', 'https://stock.9fzt.com/index/sh_605133.html', 'https://stock.9fzt.com/index/sz_001311.html', 'https://stock.9fzt.com/index/sz_002356.html', 'https://stock.9fzt.com/index/sh_603290.html', 'https://stock.9fzt.com/index/sh_600118.html', 'https://stock.9fzt.com/index/sz_002535.html', 'https://stock.9fzt.com/index/sz_002813.html', 'https://stock.9fzt.com/index/sz_002055.html', 'https://stock.9fzt.com/index/sz_002428.html', 'https://stock.9fzt.com/index/sz_002576.html', 'https://stock.9fzt.com/index/sz_002920.html']
# 2023-07-04 19:00:53,112 - INFO: scraping 公司资料...
# 2023-07-04 19:00:57,451 - INFO: scraping https://stock.9fzt.com/index/bj_833533.html...
# 2023-07-04 19:00:58,232 - INFO: scraping 公司资料...
# 2023-07-04 19:01:01,195 - INFO: scraping https://stock.9fzt.com/index/sz_301007.html...
# 2023-07-04 19:01:01,832 - INFO: scraping 公司资料...
# 2023-07-04 19:01:05,487 - INFO: scraping https://stock.9fzt.com/index/sz_301255.html...
# 2023-07-04 19:01:06,204 - INFO: scraping 公司资料...
# 2023-07-04 19:01:09,312 - INFO: scraping https://stock.9fzt.com/index/sz_300489.html...
# 2023-07-04 19:01:09,969 - INFO: scraping 公司资料...
# 2023-07-04 19:01:13,628 - INFO: scraping https://stock.9fzt.com/index/sz_301221.html...
# 2023-07-04 19:01:14,233 - INFO: scraping 公司资料...
# 2023-07-04 19:01:17,460 - INFO: scraping https://stock.9fzt.com/index/sz_300552.html...
# 2023-07-04 19:01:18,021 - INFO: scraping 公司资料...
# 2023-07-04 19:01:21,670 - INFO: scraping https://stock.9fzt.com/index/sh_688280.html...
# 2023-07-04 19:01:22,272 - INFO: scraping 公司资料...
# 2023-07-04 19:01:25,809 - INFO: scraping https://stock.9fzt.com/index/sz_300503.html...
# 2023-07-04 19:01:27,366 - INFO: scraping 公司资料...
# 2023-07-04 19:01:30,574 - INFO: scraping https://stock.9fzt.com/index/sz_300549.html...
# 2023-07-04 19:01:31,480 - INFO: scraping 公司资料...
# 2023-07-04 19:01:34,756 - INFO: scraping https://stock.9fzt.com/index/sh_688331.html...
# 2023-07-04 19:01:35,443 - INFO: scraping 公司资料...
# 2023-07-04 19:01:39,036 - INFO: scraping https://stock.9fzt.com/index/bj_831278.html...
# 2023-07-04 19:01:39,729 - INFO: scraping 公司资料...
# 2023-07-04 19:01:40,683 - INFO: scraping https://stock.9fzt.com/index/sh_688147.html...
# 2023-07-04 19:01:41,414 - INFO: scraping 公司资料...
# 2023-07-04 19:01:44,727 - INFO: scraping https://stock.9fzt.com/index/sh_688123.html...
# 2023-07-04 19:01:45,418 - INFO: scraping 公司资料...
# 2023-07-04 19:01:48,652 - INFO: scraping https://stock.9fzt.com/index/bj_836221.html...
# 2023-07-04 19:01:49,263 - INFO: scraping 公司资料...
# 2023-07-04 19:01:51,966 - INFO: scraping https://stock.9fzt.com/index/sh_688326.html...
# 2023-07-04 19:01:52,556 - INFO: scraping 公司资料...
# 2023-07-04 19:01:55,469 - INFO: scraping https://stock.9fzt.com/index/sz_301099.html...
# 2023-07-04 19:01:56,031 - INFO: scraping 公司资料...
# 2023-07-04 19:01:59,487 - INFO: scraping https://stock.9fzt.com/index/sh_688071.html...
# 2023-07-04 19:02:00,529 - INFO: scraping 公司资料...
# 2023-07-04 19:02:03,588 - INFO: scraping https://stock.9fzt.com/index/sz_300496.html...
# 2023-07-04 19:02:04,272 - INFO: scraping 公司资料...
# 2023-07-04 19:02:07,903 - INFO: scraping https://stock.9fzt.com/index/sz_301183.html...
# 2023-07-04 19:02:08,457 - INFO: scraping 公司资料...
# 2023-07-04 19:02:11,609 - INFO: scraping https://stock.9fzt.com/index/sz_301488.html...
# 2023-07-04 19:02:12,395 - INFO: scraping 公司资料...
# 2023-07-04 19:02:15,280 - INFO: scraping https://stock.9fzt.com/index/bj_833533.html...
# 2023-07-04 19:02:15,939 - INFO: scraping 公司资料...
# 2023-07-04 19:02:16,796 - INFO: scraping https://stock.9fzt.com/index/sz_301007.html...
# 2023-07-04 19:02:17,578 - INFO: scraping 公司资料...
# 2023-07-04 19:02:21,146 - INFO: scraping https://stock.9fzt.com/index/sz_301255.html...
# 2023-07-04 19:02:21,908 - INFO: scraping 公司资料...
# 2023-07-04 19:02:25,242 - INFO: scraping https://stock.9fzt.com/index/sz_300489.html...
# 2023-07-04 19:02:25,819 - INFO: scraping 公司资料...
# 2023-07-04 19:02:28,958 - INFO: scraping https://stock.9fzt.com/index/sz_301221.html...
# 2023-07-04 19:02:29,540 - INFO: scraping 公司资料...
# 2023-07-04 19:02:32,756 - INFO: scraping https://stock.9fzt.com/index/sz_300552.html...
# 2023-07-04 19:02:33,402 - INFO: scraping 公司资料...
# 2023-07-04 19:02:37,071 - INFO: scraping https://stock.9fzt.com/index/sh_688280.html...
# 2023-07-04 19:02:37,682 - INFO: scraping 公司资料...
# 2023-07-04 19:02:40,787 - INFO: scraping https://stock.9fzt.com/index/sz_300503.html...
# 2023-07-04 19:02:41,424 - INFO: scraping 公司资料...
# 2023-07-04 19:02:44,691 - INFO: scraping https://stock.9fzt.com/index/sz_300549.html...
# 2023-07-04 19:02:45,278 - INFO: scraping 公司资料...
# 2023-07-04 19:02:48,935 - INFO: scraping https://stock.9fzt.com/index/sh_688331.html...
# 2023-07-04 19:02:49,524 - INFO: scraping 公司资料...
# 2023-07-04 19:02:52,805 - INFO: scraping https://stock.9fzt.com/index/bj_831278.html...
# 2023-07-04 19:02:53,355 - INFO: scraping 公司资料...
# 2023-07-04 19:02:56,469 - INFO: scraping https://stock.9fzt.com/index/sh_688147.html...
# 2023-07-04 19:02:57,073 - INFO: scraping 公司资料...
# 2023-07-04 19:03:00,373 - INFO: scraping https://stock.9fzt.com/index/sh_688123.html...
# 2023-07-04 19:03:01,025 - INFO: scraping 公司资料...
# 2023-07-04 19:03:04,799 - INFO: scraping https://stock.9fzt.com/index/bj_836221.html...
# 2023-07-04 19:03:05,654 - INFO: scraping 公司资料...
# 2023-07-04 19:03:08,972 - INFO: scraping https://stock.9fzt.com/index/sh_688326.html...
# 2023-07-04 19:03:09,614 - INFO: scraping 公司资料...
# 2023-07-04 19:03:12,983 - INFO: scraping https://stock.9fzt.com/index/sz_301099.html...
# 2023-07-04 19:03:13,611 - INFO: scraping 公司资料...
# 2023-07-04 19:03:16,623 - INFO: scraping https://stock.9fzt.com/index/sh_688071.html...
# 2023-07-04 19:03:17,304 - INFO: scraping 公司资料...
# 2023-07-04 19:03:20,715 - INFO: scraping https://stock.9fzt.com/index/sz_300496.html...
# 2023-07-04 19:03:23,161 - INFO: scraping 公司资料...
# 2023-07-04 19:03:28,719 - INFO: scraping https://stock.9fzt.com/index/sz_301183.html...
# 2023-07-04 19:03:29,729 - INFO: scraping 公司资料...
# 2023-07-04 19:03:32,037 - INFO: scraping https://stock.9fzt.com/index/sz_301023.html...
# 2023-07-04 19:03:33,039 - INFO: scraping 公司资料...
# 2023-07-04 19:03:36,254 - INFO: scraping https://stock.9fzt.com/index/bj_838837.html...
# 2023-07-04 19:03:36,777 - INFO: scraping 公司资料...
# 2023-07-04 19:03:39,619 - INFO: scraping https://stock.9fzt.com/index/bj_830839.html...
# 2023-07-04 19:03:40,158 - INFO: scraping 公司资料...
# 2023-07-04 19:03:43,248 - INFO: scraping https://stock.9fzt.com/index/sh_688368.html...
# 2023-07-04 19:03:44,133 - INFO: scraping 公司资料...
# 2023-07-04 19:03:47,838 - INFO: scraping https://stock.9fzt.com/index/sz_300095.html...
# 2023-07-04 19:03:48,572 - INFO: scraping 公司资料...
# 2023-07-04 19:03:52,396 - INFO: scraping https://stock.9fzt.com/index/sz_300273.html...
# 2023-07-04 19:03:53,139 - INFO: scraping 公司资料...
# 2023-07-04 19:03:56,657 - INFO: scraping https://stock.9fzt.com/index/sz_300558.html...
# 2023-07-04 19:03:57,347 - INFO: scraping 公司资料...
# 2023-07-04 19:04:00,183 - INFO: scraping https://stock.9fzt.com/index/sz_300928.html...
# 2023-07-04 19:04:00,874 - INFO: scraping 公司资料...
# 2023-07-04 19:04:04,015 - INFO: scraping https://stock.9fzt.com/index/sz_300044.html...
# 2023-07-04 19:04:04,588 - INFO: scraping 公司资料...
# 2023-07-04 19:04:07,670 - INFO: scraping https://stock.9fzt.com/index/bj_430418.html...
# 2023-07-04 19:04:08,229 - INFO: scraping 公司资料...
# 2023-07-04 19:04:11,395 - INFO: scraping https://stock.9fzt.com/index/sz_000691.html...
# 2023-07-04 19:04:12,288 - INFO: scraping 公司资料...
# 2023-07-04 19:04:15,849 - INFO: scraping https://stock.9fzt.com/index/sh_601279.html...
# 2023-07-04 19:04:16,564 - INFO: scraping 公司资料...
# 2023-07-04 19:04:19,886 - INFO: scraping https://stock.9fzt.com/index/sh_600742.html...
# 2023-07-04 19:04:20,444 - INFO: scraping 公司资料...
# 2023-07-04 19:04:24,072 - INFO: scraping https://stock.9fzt.com/index/bj_830896.html...
# 2023-07-04 19:04:24,765 - INFO: scraping 公司资料...
# 2023-07-04 19:04:27,611 - INFO: scraping https://stock.9fzt.com/index/sz_002211.html...
# 2023-07-04 19:04:28,300 - INFO: scraping 公司资料...
# 2023-07-04 19:04:31,795 - INFO: scraping https://stock.9fzt.com/index/sz_002703.html...
# 2023-07-04 19:04:32,431 - INFO: scraping 公司资料...
# 2023-07-04 19:04:35,964 - INFO: scraping https://stock.9fzt.com/index/sz_002355.html...
# 2023-07-04 19:04:37,750 - INFO: scraping 公司资料...
# 2023-07-04 19:04:41,443 - INFO: scraping https://stock.9fzt.com/index/sh_603178.html...
# 2023-07-04 19:04:42,211 - INFO: scraping 公司资料...
# 2023-07-04 19:04:45,186 - INFO: scraping https://stock.9fzt.com/index/sz_002583.html...
# 2023-07-04 19:04:46,010 - INFO: scraping 公司资料...
# 2023-07-04 19:04:49,825 - INFO: scraping https://stock.9fzt.com/index/sz_002196.html...
# 2023-07-04 19:04:50,662 - INFO: scraping 公司资料...
# 2023-07-04 19:04:54,182 - INFO: scraping https://stock.9fzt.com/index/sh_603037.html...
# 2023-07-04 19:04:54,914 - INFO: scraping 公司资料...
# 2023-07-04 19:04:58,243 - INFO: scraping https://stock.9fzt.com/index/sz_000020.html...
# 2023-07-04 19:05:00,068 - INFO: scraping 公司资料...
# 2023-07-04 19:05:03,646 - INFO: scraping https://stock.9fzt.com/index/sh_603015.html...
# 2023-07-04 19:05:04,488 - INFO: scraping 公司资料...
# 2023-07-04 19:05:07,629 - INFO: scraping https://stock.9fzt.com/index/sh_603045.html...
# 2023-07-04 19:05:08,593 - INFO: scraping 公司资料...
# 2023-07-04 19:05:12,231 - INFO: scraping https://stock.9fzt.com/index/sh_603085.html...
# 2023-07-04 19:05:13,059 - INFO: scraping 公司资料...
# 2023-07-04 19:05:16,987 - INFO: scraping https://stock.9fzt.com/index/sz_002403.html...
# 2023-07-04 19:05:18,132 - INFO: scraping 公司资料...
# 2023-07-04 19:05:21,573 - INFO: scraping https://stock.9fzt.com/index/sz_301052.html...
# 2023-07-04 19:05:22,530 - INFO: scraping 公司资料...
# 2023-07-04 19:05:26,031 - INFO: scraping https://stock.9fzt.com/index/sz_002976.html...
# 2023-07-04 19:05:26,982 - INFO: scraping 公司资料...
# 2023-07-04 19:05:30,357 - INFO: scraping https://stock.9fzt.com/index/sz_002653.html...
# 2023-07-04 19:05:31,496 - INFO: scraping 公司资料...
# 2023-07-04 19:05:34,705 - INFO: scraping https://stock.9fzt.com/index/sh_605133.html...
# 2023-07-04 19:05:35,265 - INFO: scraping 公司资料...
# 2023-07-04 19:05:38,605 - INFO: scraping https://stock.9fzt.com/index/sz_001311.html...
# 2023-07-04 19:05:39,392 - INFO: scraping 公司资料...
# 2023-07-04 19:05:42,521 - INFO: scraping https://stock.9fzt.com/index/sz_002356.html...
# 2023-07-04 19:05:43,371 - INFO: scraping 公司资料...
# 2023-07-04 19:05:46,240 - INFO: scraping https://stock.9fzt.com/index/sh_603290.html...
# 2023-07-04 19:05:46,814 - INFO: scraping 公司资料...
# 2023-07-04 19:05:50,005 - INFO: scraping https://stock.9fzt.com/index/sh_600118.html...
# 2023-07-04 19:05:50,644 - INFO: scraping 公司资料...
# 2023-07-04 19:05:53,903 - INFO: scraping https://stock.9fzt.com/index/sz_002535.html...
# 2023-07-04 19:05:54,570 - INFO: scraping 公司资料...
# 2023-07-04 19:05:58,094 - INFO: scraping https://stock.9fzt.com/index/sz_002813.html...
# 2023-07-04 19:05:58,748 - INFO: scraping 公司资料...
# 2023-07-04 19:06:01,594 - INFO: scraping https://stock.9fzt.com/index/sz_002055.html...
# 2023-07-04 19:06:02,529 - INFO: scraping 公司资料...
# 2023-07-04 19:06:05,529 - INFO: scraping https://stock.9fzt.com/index/sz_002428.html...
# 2023-07-04 19:06:06,189 - INFO: scraping 公司资料...
# 2023-07-04 19:06:09,335 - INFO: scraping https://stock.9fzt.com/index/sz_002576.html...
# 2023-07-04 19:06:09,899 - INFO: scraping 公司资料...
# 2023-07-04 19:06:11,131 - INFO: scraping https://stock.9fzt.com/index/sz_002920.html...
# 2023-07-04 19:06:11,892 - INFO: scraping 公司资料...
